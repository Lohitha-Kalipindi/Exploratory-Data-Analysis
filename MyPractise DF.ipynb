# %%
# Data Frames
# SYNTAX: 
# pd.DataFrame(Data, index, columns, dtype, copy)

# %%
# Creating dataframes
# list
# dict
# nd arrays
# series
# another dataframe

# %%
import pandas as pd
df = pd.DataFrame()

# %%
# creating df using list
data = [3,5,22,56,90,34.3,11]
df = pd.DataFrame(data)
df
# Out:
#       0
# 0   3.0
# 1   5.0
# 2  22.0
# 3  56.0
# 4  90.0
# 5  34.3
# 6  11.0

# %%
data = [['dog','bark'],['cat','meow'],['cow','moo']]
df = pd.DataFrame(data, columns = ['Animal_Name','Animal_Sound'])
df
# Out:
#   Animal_Name Animal_Sound
# 0         dog         bark
# 1         cat         meow
# 2         cow          moo

# %%
# data = [['dog','bark'],['cat','meow'],['cow','moo']]
# df = pd.DataFrame(data, columns = ['Animal_Name'])
# df
# Gives error as there is only one col heading given but mentioned 2 cols

# %%
# Creating df using dictionary
data = {'Name':['Lohi','Swathi','Rahul'],'Age':[18,20,21]}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age
# 0    Lohi   18
# 1  Swathi   20
# 2   Rahul   21

# %%
data = {'Name':['Lohi','Swathi','Rahul'],'Age':[18,20,21]}
df = pd.DataFrame(data, index = ['a','b','c'])
df
# If given more indeces, it gives an error
# Out:
#      Name  Age
# a    Lohi   18
# b  Swathi   20
# c   Rahul   21

# %%
data = {'Karan_Marks':pd.Series([50,77,65], index = ['Test-1','Test-2','Test-3']),'Arjun_Marks':pd.Series([56,34,90,11,34], index = ['Test 1','Ptest 1','Test 2','Ptest 2','Test 3'])}
df = pd.DataFrame(data, columns = ['A','B'], index = ['AA','BB'])
# df = pd.DataFrame(data, index = ['A','B'])   ---- Gives null values to these columns
df = pd.DataFrame(data)
df
# Out:
#          Karan_Marks  Arjun_Marks
# Ptest 1          NaN         34.0
# Ptest 2          NaN         11.0
# Test 1           NaN         56.0
# Test 2           NaN         90.0
# Test 3           NaN         34.0
# Test-1          50.0          NaN
# Test-2          77.0          NaN
# Test-3          65.0          NaN

# %%
# If columns headings are changed to A & B and all the values -> NaN
# If only columns headings are changed to A & B but the data remain the same

# %%
# Create a data from from a list of dictionaries
data = [{'A':1,'B':2},{'C':3},{'D':4,'E':5},{'F':6}]
df = pd.DataFrame(data)
df
# Out:
#      A    B    C    D    E    F
# 0  1.0  2.0  NaN  NaN  NaN  NaN
# 1  NaN  NaN  3.0  NaN  NaN  NaN
# 2  NaN  NaN  NaN  4.0  5.0  NaN
# 3  NaN  NaN  NaN  NaN  NaN  6.0

# %%
data = [{'A':1,'B':2},{'C':3},{'D':4,'E':5},{'F':6}]
df = pd.DataFrame(data, index = ['W','X','Y','Z'])
df
# Out:
#      A    B    C    D    E    F
# W  1.0  2.0  NaN  NaN  NaN  NaN
# X  NaN  NaN  3.0  NaN  NaN  NaN
# Y  NaN  NaN  NaN  4.0  5.0  NaN
# Z  NaN  NaN  NaN  NaN  NaN  6.0

# %%
data = [{'A':1,'B':2},{'C':3},{'D':4,'E':5},{'F':6}]
df = pd.DataFrame(data, index = ['W','X','Y','Z'], columns = ['x','y','z','a','b','c'])
df
# Out:
#     x   y   z   a   b   c
# W NaN NaN NaN NaN NaN NaN
# X NaN NaN NaN NaN NaN NaN
# Y NaN NaN NaN NaN NaN NaN
# Z NaN NaN NaN NaN NaN NaN

# %%
# Updation
data = [10,20,30,40,50,60,70]
df = pd.DataFrame(data, columns = ['Marks'])
df
# Out:
#    Marks
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     70

# %%
data = [10,20,30,40,50,60,70]
data1 = [100,200,300,400,500,600,700]
df = pd.DataFrame([data,data1], columns = ['A','B','C','D','E','F','G'])
df
# Out:
#      A    B    C    D    E    F    G
# 0   10   20   30   40   50   60   70
# 1  100  200  300  400  500  600  700

# %%
df['B']
# Out:
# 0     20
# 1    200
# Name: B, dtype: int64

# %%
# Adding a column
df['H'] = [56,78]
df
# Out:
#      A    B    C    D    E    F    G   H
# 0   10   20   30   40   50   60   70  56
# 1  100  200  300  400  500  600  700  78

# %%
# df[3] = [12,23,34,56,45,56,78,76]
# df  
# Gives error

# %%
df['M'] = pd.Series([56,78,89])
df   # --- Only 2 are added
# Out:
#      A    B    C    D    E    F    G   H   M
# 0   10   20   30   40   50   60   70  56  56
# 1  100  200  300  400  500  600  700  78  78

# %%
df['N' ] = pd.Series([56])
df  #--- adds NaN values for remaining
# Out:
#      A    B    C    D    E    F    G   H   M     N
# 0   10   20   30   40   50   60   70  56  56  56.0
# 1  100  200  300  400  500  600  700  78  78   NaN

# %%
df['Z'] = pd.Series([1,2,3,4], index = [2,3,0,1])
df   #------ adds the values that matches the indices
# Out:
#      A    B    C    D    E    F    G   H   M     N  Z
# 0   10   20   30   40   50   60   70  56  56  56.0  3
# 1  100  200  300  400  500  600  700  78  78   NaN  4

# %%
df['Y'] = pd.Series([1,2,3,4], index = [0,1,2,3])
df
# Out:
#      A    B    C    D    E    F    G   H   M     N  Z  Y
# 0   10   20   30   40   50   60   70  56  56  56.0  3  1
# 1  100  200  300  400  500  600  700  78  78   NaN  4  2

# %%
df['Z'] = pd.Series([1,2,3,4], index = [2,3,5,1])
df
# Out:
#      A    B    C    D    E    F    G   H   M     N    Z  Y   W
# 0   10   20   30   40   50   60   70  56  56  56.0  NaN  1 NaN
# 1  100  200  300  400  500  600  700  78  78   NaN  4.0  2 NaN

# %%
df['W'] = pd.Series([1,2,3,4], index = ['A','B','C','D'])
df
# Indices values not matched
# Out:
#      A    B    C    D    E    F    G   H   M     N    Z  Y   W
# 0   10   20   30   40   50   60   70  56  56  56.0  NaN  1 NaN
# 1  100  200  300  400  500  600  700  78  78   NaN  4.0  2 NaN

# %%
# Delete a column
del df['W']
df
# Out:
#      A    B    C    D    E    F    G   H   M     N    Z  Y
# 0   10   20   30   40   50   60   70  56  56  56.0  NaN  1
# 1  100  200  300  400  500  600  700  78  78   NaN  4.0  2

# %%
# pop function
df.pop('G')    #----- returns the deleted item
# Out:
# 0     70
# 1    700
# Name: G, dtype: int64

# %%
df
# Out:
#      A    B    C    D    E    F   H   M     N    Z  Y
# 0   10   20   30   40   50   60  56  56  56.0  NaN  1
# 1  100  200  300  400  500  600  78  78   NaN  4.0  2

# %%
print(df['C'])  # ----- gives values
df[['C']]   # ----- gives in the form of dataframe
# Out:
# 0     30
# 1    300
# Name: C, dtype: int64
#      C
# 0   30
# 1  300

# %%
df[['E','A','N','A']]
# Out:
#      E    A     N    A
# 0   50   10  56.0   10
# 1  500  100   NaN  100

# %%
# df['E','A','N','A']    It gives an error

# %%
# del df[['E','A']]  ---- GIVES error --- we can delete only a single column at once

# %%
df
# Out:
#      A    B    C    D    E    F   H   M     N    Z  Y
# 0   10   20   30   40   50   60  56  56  56.0  NaN  1
# 1  100  200  300  400  500  600  78  78   NaN  4.0  2

# %%
# df.pop(['D','Y'])  # -------- error
# df

# We can conclude that the functionality of del is same as pop

# %%
# Drop
df.drop(['D','Y'], axis = 1)
df 
# Axis is necessary ---- by default the axis = 0
# Temporary delete
# Drop can delete multiple items at once
# del and pop deletes permanently 
# drop is to our choice (using inplace, we can delete permanently)
# Out:
#      A    B    C    D    E    F   H   M     N    Z  Y
# 0   10   20   30   40   50   60  56  56  56.0  NaN  1
# 1  100  200  300  400  500  600  78  78   NaN  4.0  2

# %%
df['P'] = df['E'] + df['N']
df
# any arithmetic operation with NaN is also NaN
# Out:
#      A    B    C    D    E    F   H   M     N    Z  Y      P
# 0   10   20   30   40   50   60  56  56  56.0  NaN  1  106.0
# 1  100  200  300  400  500  600  78  78   NaN  4.0  2    NaN

# %%
df1 = [{'A':45, 'B':98, 'P':104}]
df1
# Out:
# [{'A': 45, 'B': 98, 'P': 104}]

# %%
# df = df.append(df1)
# df

# Gives an error
# Used to work till the version 1.4.0
# One such methods is pandas. DataFrame. append() that has been deprecated since pandas version 1.4. 0 (the same applies for the Series API, pandas.

# %%
# Insert method
# df.insert(location, name_of_column, data)

# df.insert(5,'bbye',[100,200,300])
df.insert(2,'bank',500)
df
# Out:
#      A    B  bank  bbye    C    D    E    F   H   M     N    Z  Y      P
# 0   10   20   500   100   30   40   50   60  56  56  56.0  NaN  1  106.0
# 1  100  200   500   200  300  400  500  600  78  78   NaN  4.0  2    NaN

# %%
df
# Out:
#      A    B  bank  bbye    C    D    E    F   H   M     N    Z  Y      P
# 0   10   20   500   100   30   40   50   60  56  56  56.0  NaN  1  106.0
# 1  100  200   500   200  300  400  500  600  78  78   NaN  4.0  2    NaN
